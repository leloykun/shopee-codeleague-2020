# %%
import subprocess

def run_command(command):
    process = subprocess.Popen(command.split(), stdout=subprocess.PIPE)
    return process.communicate()

# %% [markdown]
# ## Install libraries

# %% [markdown]
# ### Install Apex

# %%
# !git clone https://github.com/NVIDIA/apex.git
# Out:
# Cloning into 'apex'...
# remote: Enumerating objects: 7335, done.
# remote: Total 7335 (delta 0), reused 0 (delta 0), pack-reused 7335
# Receiving objects: 100% (7335/7335), 13.87 MiB | 21.53 MiB/s, done.
# Resolving deltas: 100% (4957/4957), done.

# %%
cd apex
# Out:
# /content/apex

# %%
# !pip3 install -v --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" ./
# Out:
# /usr/local/lib/python3.6/dist-packages/pip/_internal/commands/install.py:283: UserWarning: Disabling all use of wheels due to the use of --build-options / --global-options / --install-options.
#   cmdoptions.check_install_build_global(options)
# Created temporary directory: /tmp/pip-ephem-wheel-cache-zaah3u8t
# Created temporary directory: /tmp/pip-req-tracker-m8_auau1
# Created requirements tracker '/tmp/pip-req-tracker-m8_auau1'
# Created temporary directory: /tmp/pip-install-s1_cjyrh
# Processing /content/apex
#   Created temporary directory: /tmp/pip-req-build-jvd1n9y5
#   Added file:///content/apex to build tracker '/tmp/pip-req-tracker-m8_auau1'
#     Running setup.py (path:/tmp/pip-req-build-jvd1n9y5/setup.py) egg_info for package from file:///content/apex
#     Running command python setup.py egg_info
#
#
#     torch.__version__  = 1.5.1+cu101
#
#
#     running egg_info
#     creating /tmp/pip-req-build-jvd1n9y5/pip-egg-info/apex.egg-info
# ...

# %%
cd ../
# Out:
# /content

# %% [markdown]
# ### Install MASS

# %%
# !git clone https://github.com/leloykun/MASS.git
# Out:
# Cloning into 'MASS'...
# remote: Enumerating objects: 127, done.
# remote: Total 127 (delta 0), reused 0 (delta 0), pack-reused 127
# Receiving objects: 100% (127/127), 159.44 MiB | 24.56 MiB/s, done.
# Resolving deltas: 100% (19/19), done.
# Checking out files: 100% (106/106), done.

# %%
cd MASS/MASS-unsupNMT/
# Out:
# /content/MASS/MASS-unsupNMT

# %%
ls
# Out:
# data/                           install-tools.sh    tools/
# filter_noisy_data.py            prepare_dataset.sh  train.py
# get-data-bilingual-enro-nmt.sh  preprocess.py       translate_ensemble.py
# get-data-gigaword.sh            pretrain.sh         translate.py
# get-data-nmt.sh                 src/

# %% [markdown]
# ### Train MASS

# %%
# !python3 train.py --dump_path ./dumped/ --exp_name unsupMT_zhen --save_periodic 1 --encoder_only false \
--emb_dim 384 --n_layers 6 --n_dec_layers 6 --n_heads 6 --dropout 0.1 --attention_dropout 0.1 --gelu_activation true \
--word_mass 0.5 --data_path ./data/processed/en-zh/ --lgs en-zh --bptt 64 --min_len 5 --max_len 64 --tokens_per_batch 3000 \
--optimizer adam_inverse_sqrt,beta1=0.9,beta2=0.98,lr=0.0001 --epoch_size 50000 --max_epoch 100 --mass_steps en,zh \
--eval_bleu true                                     \
# Out:
# mono_dataset:
# ./data/processed/en-zh/train.en.pth True
# ./data/processed/en-zh/valid.en.pth True
# ./data/processed/en-zh/test.en.pth True
# ./data/processed/en-zh/train.zh.pth True
# ./data/processed/en-zh/valid.zh.pth True
# ./data/processed/en-zh/test.zh.pth True
# para_dataset:
# ./data/processed/en-zh/valid.en-zh.en.pth True
# ./data/processed/en-zh/valid.en-zh.zh.pth True
# ./data/processed/en-zh/test.en-zh.en.pth True
# ./data/processed/en-zh/test.en-zh.zh.pth True
# SLURM job: False
# 0 - Number of nodes: 1
# 0 - Node ID        : 0
# 0 - Local rank     : 0
# 0 - Global rank    : 0
# 0 - World size     : 1
# 0 - GPUs per node  : 1
# 0 - Master         : True
# 0 - Multi-node     : False
# 0 - Multi-GPU      : False
# 0 - Hostname       : a8edb3d854c4
# None
# INFO - 07/16/20 06:59:57 - 0:00:00 - ============ Initialized logger ============
# INFO - 07/16/20 06:59:57 - 0:00:00 - ae_steps: []
#                                      asm: False
# ...
