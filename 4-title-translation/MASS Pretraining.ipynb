# %%
import subprocess

def run_command(command):
    process = subprocess.Popen(command.split(), stdout=subprocess.PIPE)
    return process.communicate()

# %% [markdown]
# ## Install libraries

# %%
# !pip install -q fairseq==0.7.1

# %% [markdown]
# ### Install Apex

# %%
# !rm -r apex

# %%
# !git clone https://github.com/NVIDIA/apex.git

# %%
cd apex

# %%
# %%time
# !pip3 install -v -q --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" ./

# %%
cd ../

# %% [markdown]
# ### Install MASS

# %%
# !git clone https://github.com/leloykun/MASS.git
# Out:
# Cloning into 'MASS'...
# remote: Enumerating objects: 65, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 1221 (delta 25), reused 44 (delta 13), pack-reused 1156
# Receiving objects: 100% (1221/1221), 419.91 MiB | 29.40 MiB/s, done.
# Resolving deltas: 100% (538/538), done.
# Checking out files: 100% (185/185), done.

# %%
cd MASS/MASS-supNMT
# Out:
# /kaggle/working/MASS/MASS-supNMT

# %%
ls
# Out:
# README.md              data/                  mass/                translate.sh
# archi_mass_sup.png     ft_mass_enzh.sh        run_mass_enzh.sh
# archi_mass_sup_md.png  generate_enzh_data.sh  run_mass_enzh_pc.sh

# %%
# !git pull
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 5 (delta 3), reused 5 (delta 3), pack-reused 0
# Unpacking objects: 100% (5/5), done.
# From https://github.com/leloykun/MASS
#    e9f6b75..aa4e00d  master     -> origin/master
# Updating e9f6b75..aa4e00d
# Fast-forward
#  title-translation/preprocess_dataset.sh               |  18 +++++++++---------
#  .../processed/{test.zh-en.en => test.en-zh.en}        |   0
#  .../{test.zh-en.en.bin => test.en-zh.en.bin}          | Bin
#  .../{test.zh-en.en.idx => test.en-zh.en.idx}          | Bin
#  .../{test.zh-en.en.pth => test.en-zh.en.pth}          | Bin
#  .../processed/{test.zh-en.zh => test.en-zh.zh}        |   0
#  .../{test.zh-en.zh.bin => test.en-zh.zh.bin}          | Bin
#  .../{test.zh-en.zh.idx => test.en-zh.zh.idx}          | Bin
#  .../{test.zh-en.zh.pth => test.en-zh.zh.pth}          | Bin
#  9 files changed, 9 insertions(+), 9 deletions(-)
#  rename title-translation/processed/{test.zh-en.en => test.en-zh.en} (100%)
#  rename title-translation/processed/{test.zh-en.en.bin => test.en-zh.en.bin} (100%)
#  rename title-translation/processed/{test.zh-en.en.idx => test.en-zh.en.idx} (100%)
#  rename title-translation/processed/{test.zh-en.en.pth => test.en-zh.en.pth} (100%)
#  rename title-translation/processed/{test.zh-en.zh => test.en-zh.zh} (100%)
#  rename title-translation/processed/{test.zh-en.zh.bin => test.en-zh.zh.bin} (100%)
#  rename title-translation/processed/{test.zh-en.zh.idx => test.en-zh.zh.idx} (100%)
#  rename title-translation/processed/{test.zh-en.zh.pth => test.en-zh.zh.pth} (100%)

# %%
ls ../title-translation/processed
# Out:
# dict.en.txt    test.en-zh.en.bin  test.en-zh.zh      test.en-zh.zh.pth
# dict.zh.txt    test.en-zh.en.idx  test.en-zh.zh.bin
# test.en-zh.en  test.en-zh.en.pth  test.en-zh.zh.idx

# %% [markdown]
# ### Load models

# %%
# !mkdir models

# %%
# !gsutil cp -r gs://shopee-title-translation/mass/models/checkpoint_kaggle_pc.pt models/checkpoint_best.pt
# Out:
# Copying gs://shopee-title-translation/mass/models/checkpoint_kaggle_sup_ft.pt...
# / [1 files][  1.1 GiB/  1.1 GiB]   89.4 MiB/s
# Operation completed over 1 objects/1.1 GiB.

# %%
ls models
# Out:
# checkpoint_best.pt

# %% [markdown]
# ## Train MASS

# %% [markdown]
# ### Pretraining

# %%
data_dir = "data/processed"
user_dir = "mass"
save_dir = "models"
model = "checkpoint_best.pt"

seed=0
max_tokens=2048 # for 16GB GPUs
update_freq=1
dropout=0.1
attention_heads=4
embed_dim=512
ffn_embed_dim=1024
encoder_layers=6
decoder_layers=4
word_mask=0.3

start_epoch = 0
for epoch in range(start_epoch, 10+1):
    # !echo "start epoch $epoch" && \
    fairseq-train $data_dir \
        --user-dir $user_dir \
        --task xmasked_seq2seq \
        --source-langs en,zh \
        --target-langs en,zh \
        --langs en,zh \
        --arch xtransformer \
        --mass_steps en-en,zh-zh \
        --memt_steps en-zh,zh-en \
        --save-dir $save_dir \
        --optimizer adam --adam-betas '(0.9, 0.98)' --clip-norm 0.0 \
        --lr-scheduler inverse_sqrt --lr 0.00005 --min-lr 1e-09 \
        --criterion label_smoothed_cross_entropy \
        --lm-bias --lazy-load --seed $seed \
        --log-format json \
        --max-tokens $max_tokens --update-freq $update_freq \
        --encoder-normalize-before  --decoder-normalize-before \
        --dropout $dropout --relu-dropout $dropout --attention-dropout $dropout \
        --decoder-attention-heads $attention_heads --encoder-attention-heads $attention_heads \
        --decoder-embed-dim $embed_dim --encoder-embed-dim $embed_dim \
        --decoder-ffn-embed-dim $ffn_embed_dim --encoder-ffn-embed-dim $ffn_embed_dim \
        --encoder-layers $encoder_layers --decoder-layers $decoder_layers \
        --max-update 100000000 --max-epoch $epoch \
        --keep-last-epochs 1 --log-interval 100 \
        --share-decoder-input-output-embed \
        --valid-lang-pairs en-zh \
        --word_mask $word_mask \
        --ddp-backend=no_c10d \
        --restore-file $model \
        --skip-invalid-size-inputs-valid-test && \
    gsutil cp models/checkpoint_best.pt gs://shopee-title-translation/mass/models/checkpoint_kaggle_pc.pt && \
    rm models/*.pt && \
    gsutil cp gs://shopee-title-translation/mass/models/checkpoint_kaggle_pc.pt models/checkpoint_best.pt

# %% [markdown]
# ### Fine-tuning

# %%
data_dir = "data/processed"
user_dir = "mass"
save_dir = "models"
model = "checkpoint_best.pt"

seed=0
max_tokens=2048 # for 16GB GPUs
update_freq=1
dropout=0.1
attention_heads=4
embed_dim=512
ffn_embed_dim=1024
encoder_layers=6
decoder_layers=4
word_mask=0.3

start_epoch = 8
for epoch in range(start_epoch, 11):
    # !echo "start epoch $epoch" && \
    fairseq-train $data_dir \
        --user-dir $user_dir \
        --task xmasked_seq2seq \
        --source-langs en,zh \
        --target-langs en,zh \
        --langs en,zh \
        --arch xtransformer \
        --mt_steps zh-en \
        --save-dir $save_dir \
        --optimizer adam --adam-betas '(0.9, 0.98)' --clip-norm 0.0 \
        --lr-scheduler inverse_sqrt --lr 0.00005 --min-lr 1e-09 \
        --criterion label_smoothed_cross_entropy \
        --lm-bias --lazy-load --seed $seed \
        --log-format json \
        --max-tokens $max_tokens --update-freq $update_freq \
        --encoder-normalize-before  --decoder-normalize-before \
        --dropout $dropout --relu-dropout $dropout --attention-dropout $dropout \
        --decoder-attention-heads $attention_heads --encoder-attention-heads $attention_heads \
        --decoder-embed-dim $embed_dim --encoder-embed-dim $embed_dim \
        --decoder-ffn-embed-dim $ffn_embed_dim --encoder-ffn-embed-dim $ffn_embed_dim \
        --encoder-layers $encoder_layers --decoder-layers $decoder_layers \
        --max-update 100000000 --max-epoch $epoch \
        --keep-last-epochs 1 --log-interval 100 \
        --share-decoder-input-output-embed \
        --valid-lang-pairs en-zh \
        --word_mask $word_mask \
        --ddp-backend=no_c10d \
        --restore-file $model \
        --skip-invalid-size-inputs-valid-test && \
    gsutil cp models/checkpoint_best.pt gs://shopee-title-translation/mass/models/checkpoint_kaggle_pc.pt && \
    rm models/*.pt && \
    gsutil cp gs://shopee-title-translation/mass/models/checkpoint_kaggle_pc.pt models/checkpoint_best.pt

# %% [markdown]
# ### Inference

# %%
# !mkdir data/results

# %%
ls ../title-translation/processed
# Out:
# dict.en.txt        test.en-zh.zh.bin  test.zh-en.en.idx  test.zh-en.zh.idx
# dict.zh.txt        test.en-zh.zh.idx  test.zh-en.en.pth  test.zh-en.zh.pth
# test.en-zh.en.bin  test.zh-en.en      test.zh-en.zh
# test.en-zh.en.idx  test.zh-en.en.bin  test.zh-en.zh.bin

# %%
model="models/checkpoint_best.pt"
data_dir="../title-translation/processed"
user_dir="mass"
results_dir="data/results"

# !fairseq-generate $data_dir \
    --user-dir $user_dir \
    -s zh -t en \
    --langs zh,en \
    --source-langs zh --target-langs en \
    --mt_steps zh-en \
    --gen-subset test \
    --task xmasked_seq2seq \
    --path $model \
    --beam 8 --remove-bpe  \
    --results-path $results_dir | tee preds.out
# Out:
#   0%|                                                    | 0/21 [00:00<?, ?it/s]/opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/ATen/native/BinaryOps.cpp:66: UserWarning: Integer division of tensors using div or / is deprecated, and in a future release div will perform true division as in Python 3. Use true_divide or floor_divide (// in Python) instead.
# Namespace(beam=8, cpu=False, criterion='cross_entropy', data='../title-translation/processed', dataset_impl='cached', diverse_beam_groups=-1, diverse_beam_strength=0.5, force_anneal=None, fp16=False, fp16_init_scale=128, fp16_scale_tolerance=0.0, fp16_scale_window=None, gen_subset='test', langs='zh,en', lazy_load=False, left_pad_source='True', left_pad_target='False', lenpen=1, lm_bias=False, log_format=None, log_interval=1000, lr_scheduler='fixed', lr_shrink=0.1, mass_steps='', match_source_len=False, max_len_a=0, max_len_b=200, max_sentences=None, max_source_positions=1024, max_target_positions=1024, max_tokens=12000, memory_efficient_fp16=False, memt_steps='', min_len=1, min_loss_scale=0.0001, model_overrides='{}', momentum=0.99, mt_steps='zh-en', nbest=1, no_beamable_mm=False, no_early_stop=False, no_progress_bar=False, no_repeat_ngram_size=0, num_shards=1, num_workers=0, optimizer='nag', path='models/checkpoint_best.pt', prefix_size=0, print_alignment=False, quiet=False, raw_text=False, reload_checkpoint=None, remove_bpe='@@ ', replace_unk=None, required_batch_size_multiple=8, results_path='data/results', sacrebleu=False, sampling=False, sampling_topk=-1, score_reference=False, seed=1, shard_id=0, skip_invalid_size_inputs_valid_test=False, source_lang='zh', source_langs='zh', target_lang='en', target_langs='en', task='xmasked_seq2seq', tbmf_wrapper=False, temperature=1.0, tensorboard_logdir='', threshold_loss_scale=None, unkpen=0, unnormalized=False, user_dir='mass', valid_lang_pairs='', warmup_updates=0, weight_decay=0.0, word_mask=0.25, word_mask_keep_rand='0.1,0.1,0.8')
# | [en] dictionary: 28778 types
# | [zh] dictionary: 56317 types
# | bilingual test en-zh.en: 10000 examples
# | bilingual test en-zh.zh: 10000 examples
# | loading model(s) from models/checkpoint_best.pt
# S-3807	ahc 神仙 水系 列 保 湿 乳霜
# T-3807	ahc fairy water series moisturizing cream
# H-3807	-0.030795099213719368	ahc fairy water series moisturizing cream
# P-3807	-0.0025 -0.0362 -0.1176 -0.0426 -0.0128 -0.0039 -0.0000
# S-6819	高画质 hd- 老鹰 之 歌 dvd
# T-6819	high definition hd-eagle song dvd
# H-6819	-0.028692247346043587	high definition hd-eagle song dvd
# P-6819	-0.1197 -0.0355 -0.0103 -0.0090 -0.0210 -0.0052 -0.0000
# S-7769	半透明 磨砂 户 外长 款 雨衣
# T-7769	translucent matte outdoor long raincoat
# H-7769	-0.051961105316877365	translucent matte outdoor long raincoat
# P-7769	-0.0004 -0.2184 -0.0883 -0.0002 -0.0044 -0.0000
# S-8700	工程 用 计算机 ca-3500 v
# T-8700	engineering computer ca-3500v
# H-8700	-0.005417960230261087	engineering computer ca-3500v
# P-8700	-0.0085 -0.0075 -0.0068 -0.0072 -0.0077 -0.0002 -0.0000
# S-3376	crystal ball (cookie damier)
# T-3376	crystal ball ( cookie damier )
# H-3376	-0.026600565761327744	crystal ball ( cookie damier )
# P-3376	-0.0018 -0.0004 -0.0003 -0.0735 -0.1100 -0.0002 -0.0000
# S-2028	复古 花卉 收 腰 开 扣 洋装
# T-2028	vintage floral waist open button dress
# H-2028	-0.07812759280204773	vintage floral waist open button dress
# P-2028	-0.3920 -0.0105 -0.0207 -0.0963 -0.0125 -0.0148 -0.0000
# S-5660	海洋 拉娜 修护 精华 油 30 ml
# T-5660	ocean lana repair essence oil 30ml
# H-5660	-0.08175196498632431	ocean lana repair essence oil 30ml
# P-5660	-0.1394 -0.0632 -0.0007 -0.3186 -0.0253 -0.0251 -0.0000
# S-4640	金牛座 牙 菌斑 对策 湿 纸巾
# T-4640	tissue plaque countermeasure wet wipes
# H-4640	-0.16387830674648285	tissue plaque countermeasure wet wipes
# P-4640	-0.4572 -0.3736 -0.0809 -0.0520 -0.0297 -0.1538 -0.0000
# S-8524	吊带 排 扣 不 规则 鱼尾 洋装
# T-8524	irregular fishtail dress with suspenders
# H-8524	-0.19459234178066254	irregular fishtail dress with suspenders
# P-8524	-0.1788 -0.0667 -0.0016 -0.4020 -0.1813 -0.5311 -0.0006
# S-9513	斜 背包 卡拉 对称 纹路 斜 背包
# T-9513	crossbody cara symmetrical crossbody bag
# H-9513	-0.1296091079711914	crossbody cara symmetrical crossbody bag
# P-9513	-0.0364 -0.7220 -0.0466 -0.0268 -0.0078 -0.0675 -0.0000
# S-3121	日本 可 清洗 式 长柄 纱窗 刷
# T-3121	japanese washable long handle screen brush
# H-3121	-0.12607139348983765	japanese washable long handle screen brush
# P-3121	-0.7017 -0.0224 -0.0142 -0.0255 -0.0995 -0.0188 -0.0003
# S-763	可爱 毛绒绒 纸巾 抽 4 款 任选
# T-763	4 cute plush plush tissues
# H-763	-0.39196357131004333	4 cute plush plush tissues
# P-763	-0.5196 -1.2254 -0.0287 -0.7433 -0.2028 -0.0239 -0.0001
# S-7400	连 帽 黑 条 宽松 牛仔 外套
# T-7400	hooded black stripe loose denim jacket
# H-7400	-0.03256048634648323	hooded black stripe loose denim jacket
# P-7400	-0.0798 -0.0004 -0.1331 -0.0015 -0.0057 -0.0074 -0.0000
# S-3439	宠物 自动 伸缩 牵 绳 5m 多色
# T-3439	pet automatic retractable leash 5m multicolor
# H-3439	-0.020480837672948837	pet automatic retractable leash 5m multicolor
# P-3439	-0.0421 -0.0120 -0.0496 -0.0323 -0.0034 -0.0039 -0.0000
# S-9165	学院 风 修身 网 纱 吊带 裙
# T-9165	college style slim mesh suspender skirt
# H-9165	-0.06918525695800781	college style slim mesh suspender skirt
# P-9165	-0.0002 -0.3107 -0.0057 -0.0193 -0.1418 -0.0067 -0.0000
# S-9073	playboy vip 男用 淡 香水 100 ml
# T-9073	playboy vip eau de toilette 100ml
# H-9073	-0.020883833989501	playboy vip eau de toilette 100ml
# P-9073	-0.0016 -0.0222 -0.0363 -0.0101 -0.0216 -0.0543 -0.0001
# S-2563	力 田 tm-b01 接触 式 温度计
# T-2563	li tian tm-b01 contact thermometer
# H-2563	-1.1865040063858032	litian tm-b01 rechargeable thermometer
# P-2563	-0.1495 -0.0239 -2.0186 -4.5546 -1.3792 -0.1797 -0.0000
# S-2942	ma-1 缩 口 长裤 life8999
# T-2942	ma-1 shrink pants life8999
# H-2942	-0.011922837235033512	ma-1 shrink pants life8999
# P-2942	-0.0033 -0.0048 -0.0654 -0.0051 -0.0005 -0.0044 -0.0000
# S-8998	受 赞颂者 dvd vol-3
# T-8998	praise dvd vol-3
# H-8998	-0.009615739807486534	praise dvd vol-3
# P-8998	-0.0518 -0.0019 -0.0005 -0.0008 -0.0026 -0.0000
# S-5509	基本 款 浅蓝 短 版 牛仔 外套
# T-5509	basic light blue short denim jacket
# H-5509	-0.04735361039638519	basic light blue short denim jacket
# P-5509	-0.0047 -0.0302 -0.0024 -0.0024 -0.2657 -0.0260 -0.0000
# S-1102	unt 玻尿酸 全 效 卸妆 水 220ml
# T-1102	unt hyaluronic acid makeup remover 220ml
# H-1102	-0.008594785816967487	unt hyaluronic acid makeup remover 220ml
# P-1102	-0.0085 -0.0055 -0.0005 -0.0347 -0.0043 -0.0067 -0.0000
# S-7490	kid 灰 蓝 迷彩 连 帽 斗篷
# T-7490	kid grey blue camouflage hooded cape
# H-7490	-0.039024628698825836	kid grey blue camouflage hooded cape
# P-7490	-0.0005 -0.0635 -0.0501 -0.0030 -0.0048 -0.1513 -0.0000
# S-1089	coach 马车 pvc 皮革 饰边 托特 包
# T-1089	coach carriage pvc leather trim tote
# H-1089	-0.029012272134423256	coach carriage pvc leather trim tote
# P-1089	-0.0004 -0.0618 -0.0009 -0.0011 -0.0025 -0.0010 -0.1354
# S-8601	fender monterey 无线 蓝 牙 喇叭
# T-8601	fender monterey wireless bluetooth speaker
# H-8601	-0.05334854498505592	fender monterey wireless bluetooth speaker
# P-8601	-0.0105 -0.0923 -0.2544 -0.0001 -0.0009 -0.0152 -0.0000
# S-5735	破洞 牛仔 修身 短裤 m050183
# T-5735	shredded denim shorts m050183
# H-5735	-0.08941614627838135	hole denim slim shorts m050183
# P-5735	-0.4241 -0.0192 -0.1165 -0.0838 -0.0036 -0.0213 -0.0467 -0.0000
# S-8748	莫 比 鸡肉 小型 成犬3kg
# T-8748	moby chicken small adult dog 3kg
# H-8748	-0.03087002970278263	moby chicken small adult dog 3kg
# P-8748	-0.0716 -0.0109 -0.0065 -0.0873 -0.0304 -0.0094 -0.0000
# S-3648	成人 极限 运动 分体 漂 移 板
# T-3648	adult extreme sports split drift board
# H-3648	-0.06721142679452896	adult extreme sports split drift board
# P-3648	-0.0096 -0.0096 -0.0068 -0.0336 -0.4035 -0.0072 -0.0002
# S-9281	jam heavy metal 无线 蓝 牙 喇叭
# T-9281	jam heavy metal wireless bluetooth speaker
# H-9281	-0.003293991321697831	jam heavy metal wireless bluetooth speaker
# P-9281	-0.0050 -0.0070 -0.0013 -0.0008 -0.0009 -0.0081 -0.0000
# S-163	lesportsac 小鸟 轻 颂 经典 化妆 包
# T-163	lesportsac classic bird cosmetic case
# H-163	-0.22393514215946198	lesportsac birdie classic cosmetic bag
# P-163	-0.0003 -0.4970 -0.0128 -0.3670 -0.6742 -0.0162 -0.0001
# S-4590	crystal ball (frame hippie)
# T-4590	crystal ball ( frame hippie )
# H-4590	-0.11019012331962585	crystal ball ( frame hippie )
# P-4590	-0.0021 -0.0010 -0.0001 -0.7032 -0.0647 -0.0002 -0.0000
# S-6287	hollister hco 经典 logo 连 帽 外套
# T-6287	hollister <<unk>> classic logo hooded jacket
# H-6287	-0.013550281524658203	hollister hco classic logo hooded jacket
# P-6287	-0.0016 -0.0040 -0.0094 -0.0000 -0.0016 -0.0619 -0.0297 -0.0001
# S-8662	百 搭 魔鬼 毡厚底 凉鞋 35-39
# T-8662	wild devil felt platform sandals 35-39
# H-8662	-0.04642064496874809	wild devil felt platform sandals 35-39
# P-8662	-0.1974 -0.0006 -0.0039 -0.1186 -0.0019 -0.0024 -0.0001
# S-5450	小朋友 万圣节 化妆舞会 服装 角色 扮演 7
# T-5450	children halloween masquerade costume cosplay 7
# H-5450	-0.022981099784374237	children halloween masquerade costume cosplay 7
# P-5450	-0.1329 -0.0030 -0.0063 -0.0066 -0.0113 -0.0008 -0.0001
# S-1504	艾迪 美 水晶 修护 凝 露 120g
# T-1504	admiral crystal repair gel 120g
# H-1504	-0.014625822193920612	admiral crystal repair gel 120g
# P-1504	-0.0079 -0.0154 -0.0029 -0.0015 -0.0670 -0.0077 -0.0000
# S-9866	笔记本 手 帐本 #ni010181
# T-9866	notebook handbook # ni010181
# H-9866	-0.018873488530516624	notebook handbook # ni010181
# P-9866	-0.1051 -0.0068 -0.0001 -0.0006 -0.0147 -0.0049 -0.0000
# S-840	最终 兵器 彼 女 dvd vol-5
# T-840	the ultimate weapon dvd vol-5
# H-840	-0.07814721018075943	the ultimate weapon dvd vol-5
# P-840	-0.2876 -0.1132 -0.1209 -0.0153 -0.0084 -0.0016 -0.0000
# S-7202	crystal ball (african craft)
# T-7202	crystal ball ( african craft )
# H-7202	-0.04132052883505821	crystal ball ( african craft )
# P-7202	-0.0039 -0.0017 -0.0001 -0.2586 -0.0233 -0.0016 -0.0000
# S-3850	日本 原装 面包 超人 新款 超人 喇叭
# T-3850	japanese original anpanman new superman horn
# H-3850	-0.06788989901542664	japan original anpanman new superman horn
# P-3850	-0.3703 -0.0156 -0.0199 -0.0004 -0.0027 -0.0663 -0.0001
# S-1604	基本 素面 拼接 网 纱 下摆 上衣
# T-1604	basic plain stitching mesh hem top
# H-1604	-0.007183892652392387	basic plain stitching mesh hem top
# P-1604	-0.0018 -0.0024 -0.0040 -0.0076 -0.0249 -0.0095 -0.0001
# S-8393	coach 经典 中 夹 均 一价
# T-8393	coach classic middle price
# H-8393	-0.39425361156463623	coach classic medium clip one size
# P-8393	-0.0001 -0.0002 -0.2612 -0.2355 -0.7219 -1.5113 -0.0295
# S-4928	coach 大 马车 logo 手 拿 包
# T-4928	coach coach logo clutch
# H-4928	-0.34980544447898865	coach big logo clutch
# P-4928	-0.0002 -1.5722 -0.1688 -0.0041 -0.0037
# S-2545	多 芬 直 顺 修护 洗发 340ml
# T-2545	dove straight repair shampoo 340ml
# H-2545	-0.018566926941275597	dove straight repair shampoo 340ml
# P-2545	-0.0152 -0.0253 -0.0368 -0.0046 -0.0295 -0.0000
# S-7398	肤蕊 清爽 洁 颜 卸妆 液
# T-7398	skin core cleansing makeup remover
# H-7398	-0.15831486880779266	skin core cleansing makeup remover
# P-7398	-0.0492 -0.0057 -0.5717 -0.3150 -0.0081 -0.0001
# S-9928	斜纹 ・红 mt 和 纸 胶带
# T-9928	twill red mt paper tape
# H-9928	-0.014077505096793175	twill red mt paper tape
# P-9928	-0.0006 -0.0017 -0.0017 -0.0787 -0.0014 -0.0004
# S-5680	emoji 表情 符号 沐浴 精 450 ml
# T-5680	emoji emoji bath essence 450ml
# H-5680	-0.05004072189331055	emoji emoji bath essence 450ml
# P-5680	-0.0013 -0.0897 -0.0320 -0.1592 -0.0180 -0.0000
# S-1755	tory burch tb logo 夹 脚 拖鞋
# T-1755	tory burch tb logo flip-flops
# H-1755	-0.02955770492553711	tory burch tb logo flip-flops
# P-1755	-0.0010 -0.0166 -0.0020 -0.0002 -0.1574 -0.0001
# S-8060	faber-castell/ 钢笔 墨水
# T-8060	faber-castell / pen ink
# H-8060	-0.10866737365722656	faber-castell / pen ink
# P-8060	-0.0007 -0.1024 -0.3997 -0.0386 -0.0020
# S-4793	受 赞颂者 dvd vol-7
# T-4793	praise dvd vol-7
# H-4793	-0.01469278335571289	praise dvd vol-7
# P-4793	-0.0675 -0.0023 -0.0004 -0.0054 -0.0125 -0.0000
# S-2031	微露 肩 条纹 扭结 长 洋装
# T-2031	strapless knotted long dress
# H-2031	-0.04111652448773384	strapless knotted long dress
# P-2031	-0.0865 -0.1093 -0.0012 -0.0085 -0.0002
# S-3071	soft 99 车身 用 美 装 贴纸
# T-3071	soft 99 body decoration stickers
# H-3071	-0.11342287063598633	soft 99 body decoration stickers
# P-3071	-0.0138 -0.0000 -0.0017 -0.6542 -0.0108 -0.0000
# S-1923	惊 爆 头 条 内幕 dvd
# T-1923	insider dvd
# H-1923	-0.6152515411376953	insider dvd
# P-1923	-1.3572 -1.1015 -0.0013 -0.0010
# S-9047	superdry 极度 干燥 连 帽 防风 外套
# T-9047	superdry hooded windbreaker
# H-9047	-0.13796329498291016	superdry extremely dry hooded windbreaker
# P-9047	-0.0019 -0.1491 -0.0160 -0.0123 -0.0043 -0.0290 -0.8895 -0.0017
# S-1487	hedgren芙 莉 系列 尼龙 中夹
# T-1487	hedgren nylon clip
# H-1487	-0.01086735725402832	hedgren nylon clip
# P-1487	-0.0040 -0.0074 -0.0320 -0.0000
# S-1746	玫瑰 水 漾 保 湿 精露
# T-1746	rose moisturizing serum
# H-1746	-0.1162412166595459	rose moisturizing serum
# P-1746	-0.0119 -0.0961 -0.3556 -0.0014
# S-6042	方形 珍珠 耳环 篓 空 设计 感
# T-6042	square pearl earrings
# H-6042	-0.1411895751953125	square pearl earrings
# P-6042	-0.0008 -0.0044 -0.0064 -0.5532
# S-3053	金牛座 年长犬 专用 牙膏 38g
# T-3053	toothpaste 38g
# H-3053	-0.09240945428609848	toothpaste 38g
# P-3053	-0.2502 -0.0269 -0.0001
# S-7210	复古格 纹 一 片 式 绑带 长裙
# T-7210	retro check one-piece strap dress
# H-7210	-0.10164372622966766	retro check one-piece strap dress
# P-7210	-0.0259 -0.0239 -0.0787 -0.3483 -0.1326 -0.0005
# S-5762	cezanne 润 彩 唇膏 402-402
# T-5762	cezanne lip gloss 402-402
# H-5762	-0.025393623858690262	cezanne lip gloss 402-402
# P-5762	-0.0023 -0.0042 -0.1601 -0.0020 -0.0058 -0.0033 -0.0000
# H-8210	-0.5444204211235046	personalized teether little animal plush toy
# P-8210	-0.8855 -1.8969 -0.7956 -0.0471 -0.1361 -0.0480 -0.0017
# S-4304	baan 贝恩 婴儿 洗发精 200 ml
# T-4304	baan baby shampoo 200ml
# H-4304	-0.023798465728759766	baan baby shampoo 200ml
# P-4304	-0.0203 -0.0059 -0.1019 -0.0080 -0.0067 -0.0000
# S-5714	威 刚 32 g c10 u1 microsd
# T-5714	adata 32g c10 u1 microsd
# H-5714	-0.5680824518203735	adata 32 g c10 microsd c10
# P-5714	-0.0400 -0.0557 -1.1148 -0.5576 -0.7776 -1.4280 -0.0029
# S-5343	终 绝蚁 家 蚂蚁 绝 5g
# T-5343	ultimate ant home ant 5g
# H-5343	-0.011724472045898438	ultimate ant home ant 5g
# P-5343	-0.0607 -0.0011 -0.0013 -0.0042 -0.0029 -0.0000
# S-5689	35w 感应 式 头 灯 20807
# T-5689	35w induction headlight 20807
# H-5689	-2.0416738986968994	jouer induction head headlight 20fx-
# P-5689	-5.8727 -0.9567 -0.8946 -1.3507 -0.0016 -5.1058 -0.1096
# S-4695	碟 煞 来 令 片 j bubu
# T-4695	disc brakes j bubu
# H-4695	-0.010412216186523438	disc brakes j bubu
# P-4695	-0.0061 -0.0316 -0.0096 -0.0012 -0.0139 -0.0000
# S-5342	威 叔叔 自动 黑 胶 反向 伞
# T-5342	uncle wei automatic vinyl reverse umbrella
# H-5342	-0.06285572052001953	uncle wei automatic vinyl reverse umbrella
# P-5342	-0.0882 -0.0176 -0.0247 -0.0462 -0.0612 -0.2018 -0.0004
# S-3354	lakme 莱 肯 发 泥 1000 ml
# T-3354	lakme 1000ml
# H-3354	-0.014454524032771587	lakme 1000ml
# P-3354	-0.0027 -0.0406 -0.0000
# S-3130	kate spade 可爱 条纹 小巧 后 背包
# T-3130	kate spade cute striped compact backpack
# H-3130	-0.04588250070810318	kate spade cute striped compact backpack
# P-3130	-0.0003 -0.0002 -0.0015 -0.0632 -0.2208 -0.0352 -0.0000
# S-7309	铜扣 基本 款 宽 版 牛仔 短裤
# T-7309	copper buckle basic wide denim shorts
# H-7309	-0.010335514321923256	copper buckle basic wide denim shorts
# P-7309	-0.0156 -0.0155 -0.0019 -0.0042 -0.0217 -0.0134 -0.0000
# S-4232	喜 年 来 牛奶 营养 饼 180g
# T-4232	happy new year milk nutrition cake 180g
# H-4232	-0.29473185539245605	hi year of milk nutrition cake 180g
# P-4232	-0.8534 -0.0953 -1.2272 -0.0126 -0.0571 -0.1076 -0.0047 -0.0000
# S-1191	贝 臣 呵护 沐浴 精 1000 ml
# T-1191	becher care bath essence 1000ml
# H-1191	-0.34454429149627686	becher care bath essence 1000ml
# P-1191	-0.0810 -2.1504 -0.0054 -0.1099 -0.0317 -0.0335 -0.0000
# S-9657	crystal ball (flower shower)
# T-9657	crystal ball ( flower shower )
# H-9657	-0.03898688778281212	crystal ball ( flower shower )
# P-9657	-0.0004 -0.0019 -0.0001 -0.0326 -0.2360 -0.0020 -0.0000
# S-4327	露得清 晚安 胶囊 保 湿 面膜 10g
# T-4327	neutrogena good night capsule moisturizing mask 10g
# H-4327	-0.005507469177246094	neutrogena good night capsule moisturizing mask 10g
# P-4327	-0.0002 -0.0089 -0.0073 -0.0019 -0.0084 -0.0129 -0.0044 -0.0000
# S-4005	大自然 发威 时: 水 dvd
# T-4005	when nature begins : water dvd
# H-4005	-0.0905873030424118	nature republic : water dvd
# P-4005	-0.0044 -0.3820 -0.0006 -0.0991 -0.0574 -0.0000
# S-9270	时尚 珍珠 开口 玫瑰 金 手环 手镯
# T-9270	fashion pearl open rose gold bangle bracelet
# H-9270	-0.1377391815185547	fashion pearl open rose gold bracelet
# P-9270	-0.4129 -0.0004 -0.1561 -0.0029 -0.0003 -0.0945 -0.2970
# S-2618	playboy 性感 兔 女郎 淡 香水 60ml
# T-2618	playboy sexy bunny eau de toilette 60ml
# H-2618	-0.03211033344268799	playboy sexy bunny eau de toilette 60ml
# P-2618	-0.0007 -0.0002 -0.2000 -0.0119 -0.0286 -0.0129 -0.0025 -0.0000
# S-627	gap 经典 款 连 帽 外套 (女)
# T-627	gap classic hooded jacket ( female )
# H-627	-0.010183572769165039	gap classic hooded jacket ( female )
# P-627	-0.0002 -0.0000 -0.0131 -0.0103 -0.0531 -0.0044 -0.0003 -0.0000
# S-8065	德国 led lenser 18650 充电 电池
# T-8065	german led lenser 18650 rechargeable battery
# H-8065	-0.7791410684585571	germany led lenser 18650 rechargeable battery
# P-8065	-0.1494 -0.0042 -0.5817 -4.2688 -0.6667 -0.5409 -0.0213 -0.0000
# S-8746	泡泡 小 鱼油 140 颗 / 包
# T-8746	bubble fish oil 140 pcs / pack
# H-8746	-0.13042032718658447	bubble fish oil 140 pcs / pack
# P-8746	-0.0095 -0.0778 -0.0266 -0.0065 -0.9074 -0.0042 -0.0114 -0.0000
# S-5825	gap 天鹅 心 套头 毛衣 (童)
# T-5825	gap swan heart pullover ( child )
# H-5825	-0.09514570236206055	gap swan heart pullover ( child )
# P-5825	-0.0004 -0.0017 -0.0007 -0.0833 -0.0269 -0.6475 -0.0007 -0.0001
# S-129	baby veil 香氛 宝贝 发香 喷雾 80g
# T-129	baby veil fragrance baby hair spray 80g
# H-129	-0.0865168571472168	baby veil fragrance baby hair spray 80g
# P-129	-0.0017 -0.0109 -0.0020 -0.0254 -0.5843 -0.0653 -0.0025 -0.0000
# S-1148	mt 2017 ss ex 系列 全 包组
# T-1148	mt 2017 ss ex series all-inclusive set
# H-1148	-0.0067986249923706055	mt 2017 ss ex series all-inclusive set
# P-1148	-0.0004 -0.0014 -0.0006 -0.0002 -0.0003 -0.0426 -0.0089 -0.0001
# S-1140	经典 黑 系列 8000 容量 行动 电源
# T-1140	classic black series 8000 capacity power bank
# H-1140	-0.14260542392730713	classic black series 8000 capacity power bank
# P-1140	-0.0004 -0.0009 -0.0126 -0.9074 -0.0089 -0.0122 -0.1985 -0.0000
# S-6178	红 玛瑙 小熊 中国 结 吊 饰
# T-6178	red agate bear chinese knot charm
# H-6178	-0.0059610097669065	red agate bear chinese knot charm
# P-6178	-0.0040 -0.0151 -0.0008 -0.0027 -0.0015 -0.0175 -0.0001
# S-9355	粉 晶 扭 片中国 结 手环
# T-9355	pink crystal twisted piece chinese knot bracelet
# H-9355	-0.08890926837921143	pink crystal twisted piece chinese knot bracelet
# P-9355	-0.1029 -0.0018 -0.4122 -0.1698 -0.0047 -0.0163 -0.0036 -0.0000
# S-4209	雪花 脆 梅 300g 臻 御行
# T-4209	snowflake crisp plum 300g zhen yu xing
# H-4209	-0.06703841686248779	snowflake crisp plum 300g zhen yu xing
# P-4209	-0.3630 -0.0181 -0.0604 -0.0092 -0.0071 -0.0733 -0.0052 -0.0000
# S-2989	福音 战士 新 剧场 版: 破 dvd
# T-2989	evangelion new theater edition : broken dvd
# H-2989	-0.018959760665893555	evangelion new theater edition : broken dvd
# P-2989	-0.0254 -0.0008 -0.0069 -0.0399 -0.0269 -0.0491 -0.0026 -0.0000
# S-2567	crystal ball (hippie show time)
# T-2567	crystal ball ( hippie show time )
# H-2567	-0.0074530839920043945	crystal ball ( hippie show time )
# P-2567	-0.0015 -0.0004 -0.0001 -0.0050 -0.0201 -0.0316 -0.0009 -0.0000
# S-8804	双层 蕾 丝 外 网 纱 长裙
# T-8804	double-layer lace outer mesh long skirt
# H-8804	-0.11233294010162354	double-layer lace outer mesh long skirt
# P-8804	-0.2574 -0.0072 -0.0019 -0.4893 -0.0051 -0.0203 -0.1174 -0.0000
# S-3770	折叠 微距 修 眉刀-3入
# T-3770	folding macro eyebrow cutter-3 into
# H-3770	-0.21359634399414062	folding macro eyebrow cutter-3 into
# P-3770	-0.0886 -0.0169 -0.0059 -1.2509 -0.2415 -0.0278 -0.0770 -0.0002
# S-4362	日本 sfida 动物 足球 大象
# T-4362	japan sfida animal football elephant
# H-4362	-0.013827085494995117	japan sfida animal football elephant
# P-4362	-0.1001 -0.0011 -0.0028 -0.0017 -0.0018 -0.0011 -0.0020 -0.0000
# S-2206	欢迎 加入 nhk ! dvd vol 04
# T-2206	welcome to nhk ! dvd vol 04
# H-2206	-0.04474663734436035	welcome to nhk ! dvd vol 04
# P-2206	-0.0023 -0.3307 -0.0108 -0.0005 -0.0036 -0.0035 -0.0065 -0.0000
# S-7365	来不及 对 你 说 dvd
# T-7365	too late to tell you dvd
# H-7365	-0.1740763634443283	too late to tell you dvd
# P-7365	-0.1197 -0.0727 -0.0127 -0.9712 -0.0410 -0.0012 -0.0000
# S-306	熊 宝贝 衣物 香 氛袋 21g
# T-306	bear baby clothing fragrance bag 21g
# H-306	-0.0077697210945189	bear baby clothing fragrance bag 21g
# P-306	-0.0085 -0.0005 -0.0019 -0.0012 -0.0059 -0.0365 -0.0000
# S-3665	日本 lucky 洗 脸 用 化妆 发带
# T-3665	japan lucky face washing makeup hairband
# H-3665	-0.06618963181972504	japan lucky face washing makeup hairband
# P-3665	-0.1538 -0.0030 -0.0132 -0.1616 -0.0575 -0.0742 -0.0001
# S-5299	am-7343e 花艺瓶
# T-5299	am-7343e floral bottle
# H-5299	-0.009546007961034775	am-7343e floral bottle
# P-5299	-0.0152 -0.0019 -0.0025 -0.0231 -0.0233 -0.0009 -0.0000
# S-7233	三星 s7 led 原 厂 皮革 套
# T-7233	samsung s7 led original leather case
# H-7233	-0.00630024541169405	samsung s7 led original leather case
# P-7233	-0.0252 -0.0144 -0.0011 -0.0010 -0.0001 -0.0014 -0.0009
# S-6596	仅 提供 限定 买家 使用 $1016
# T-6596	only limited buyers use $ 1016
# H-6596	-0.11581476032733917	only limited buyers use $ 1016
# P-6596	-0.1428 -0.4221 -0.0679 -0.0096 -0.0006 -0.1678 -0.0000
# S-6809	crystal ball (graphic wallet)
# T-6809	crystal ball ( graphic wallet )
# H-6809	-0.010366576723754406	crystal ball ( graphic wallet )
# P-6809	-0.0025 -0.0005 -0.0001 -0.0035 -0.0654 -0.0007 -0.0000
# S-5152	shimano 鞋底 板 保护套 sm-sh45
# T-5152	shimano sole protector sm-sh45
# H-5152	-0.002786908997222781	shimano sole protector sm-sh45
# P-5152	-0.0005 -0.0065 -0.0060 -0.0057 -0.0003 -0.0004 -0.0001
# S-9343	coach魔菇 造型 皮革 零钱 包
# T-9343	coach mushroom shaped leather coin purse
# H-9343	-0.012169974856078625	coach mushroom shaped leather coin purse
# P-9343	-0.0082 -0.0061 -0.0271 -0.0099 -0.0244 -0.0092 -0.0003
# S-1621	排 扣 假 两件式 牛仔裤 裙 s-l
# T-1621	buttoned fake two-piece jeans skirt sl
# H-1621	-0.057807378470897675	buttoned fake two-piece jeans skirt sl
# P-1621	-0.3144 -0.0216 -0.0057 -0.0067 -0.0463 -0.0099 -0.0000
# S-1724	玩味 豹纹 流苏 又 青包
# T-1724	playful leopard fringe and green bag
# H-1724	-0.026230132207274437	playful leopard fringe and green bag
# P-1724	-0.0087 -0.0112 -0.0269 -0.0036 -0.0785 -0.0532 -0.0015
# S-2194	创意 时尚 led 小 夜 灯 光控
# T-2194	creative fashion led night light control
# H-2194	-0.0252772755920887	creative fashion led night light control
# P-2194	-0.0001 -0.0079 -0.0015 -0.0589 -0.0086 -0.0940 -0.0060
# S-2277	斜 背包 胜利 v字 熊熊 质感 手提包
# T-2277	crossbody victory v-shaped tote bag
# H-2277	-0.09877137094736099	crossbody victory v-shaped tote bag
# P-2277	-0.3759 -0.0052 -0.0453 -0.0078 -0.1112 -0.1141 -0.0319
# S-1374	万 宝龙 pix 铂金 夹 深蓝 原子笔
# T-1374	montblanc pix platinum cyan ballpoint pen
# H-1374	-0.12096882611513138	montblanc pix platinum cyan ballpoint pen
# P-1374	-0.0129 -0.0593 -0.0068 -0.7087 -0.0323 -0.0264 -0.0004
# S-3803	jam thrill 无线 防水 蓝 牙 喇叭
# T-3803	jam thrill wireless waterproof bluetooth speaker
# H-3803	-0.0203356072306633	jam thrill wireless waterproof bluetooth speaker
# P-3803	-0.0024 -0.1253 -0.0000 -0.0011 -0.0064 -0.0071 -0.0000
# P-6539	-0.0209 -0.0266 -0.0007 -0.0012 -0.0020 -0.0081 -0.0000
# S-427	纽伦堡 大 审判 dvd
# T-427	nuremberg trial dvd
# H-427	-0.05638844892382622	nuremberg trial dvd
# P-427	-0.0215 -0.1038 -0.2401 -0.0204 -0.0082 -0.0007 -0.0000
# S-2552	max- 新 hd-10 fl 钉书机
# T-2552	max-new hd-10fl stapler
# H-2552	-0.09625830501317978	max-new hd-10fl stapler
# P-2552	-0.0092 -0.6350 -0.0067 -0.0072 -0.0044 -0.0111 -0.0003
# S-9571	现货 超 正 刷 破 牛仔 短裤
# T-9571	spot super positive brushed denim shorts
# H-9571	-0.02661936730146408	spot super positive brushed denim shorts
# P-9571	-0.0555 -0.0164 -0.0915 -0.0111 -0.0039 -0.0079 -0.0001
# S-2778	t-arts 舞动 踢踏舞 - 维尼
# T-2778	t-arts dancing tap dance-pooh
# H-2778	-0.15652593970298767	t-arts dancing dance-pooh
# P-2778	-0.0081 -0.0208 -0.8558 -0.0233 -0.0271 -0.0041
# S-8827	紫 露 黑枣 浓缩 汁330g
# T-8827	purple dew jujube juice concentrate 330g
# H-8827	-0.051318444311618805	purple dew jujube juice concentrate 330g
# P-8827	-0.0021 -0.1063 -0.0535 -0.0878 -0.0688 -0.0408 -0.0000
# S-3769	超 梦幻 led波波 气球 空 飘
# T-3769	super dreamy led balloon balloon floating
# H-3769	-0.07357747852802277	super dreamy led balloon balloon floating
# P-3769	-0.1744 -0.1562 -0.0095 -0.0117 -0.1165 -0.0466 -0.0001
# S-7997	戴 帽子 的 猫 单 盒 卖场
# T-7997	cat single box store with hat
# H-7997	-0.23186126351356506	cat single box store with store
# P-7997	-0.0595 -0.2105 -0.1061 -0.0026 -0.5757 -0.6680 -0.0006
# S-2705	可爱 图样 双 拼 色 隐形 袜
# T-2705	cute pattern double color invisible socks
# H-2705	-0.016107287257909775	cute pattern double color invisible socks
# P-2705	-0.0524 -0.0241 -0.0064 -0.0043 -0.0179 -0.0076 -0.0000
# S-378	chicco 宝贝 婴儿 润肤 油 200 ml
# T-378	chicco baby baby moisturizing oil 200ml
# H-378	-0.10639150440692902	chicco baby baby moisturizing oil 200ml
# P-378	-0.0008 -0.0001 -0.0416 -0.1668 -0.4767 -0.0587 -0.0000
# S-1450	linola 润泽 修复 面霜 50 ml
# T-1450	linola moisturizing repair cream 50ml
# H-1450	-0.006232398096472025	linola moisturizing repair cream 50ml
# P-1450	-0.0171 -0.0011 -0.0019 -0.0060 -0.0065 -0.0110 -0.0000
# S-1417	牙刷 型 粉底 刷-22190040
# T-1417	toothbrush foundation brush-22190040
# H-1417	-0.07373619079589844	toothbrush foundation brush-22190040
# P-1417	-0.0085 -0.0506 -0.1812 -0.2634 -0.0089 -0.0034 -0.0001
# S-469	{ 大卫 }上 谊 怪 叔叔
# T-469	{ david } uncle shangyi
# H-469	-0.06251321732997894	{ david } uncle shangyi
# P-469	-0.0114 -0.0534 -0.0069 -0.2443 -0.0591 -0.0623 -0.0002
# S-1545	无线 超长 待机 蓝 芽 耳机
# T-1545	wireless ultra-long standby bluetooth headset
# H-1545	-0.1622411012649536	wireless ultra-long standby bluetooth headset
# P-1545	-0.0016 -0.8696 -0.0270 -0.0749 -0.0556 -0.2250 -0.0442 -0.0000
# S-1562	可乐 熊 宝贝 2: 运动会 dvd
# T-1562	cola bear baby 2 : sports dvd
# H-1562	-0.3619941174983978	coke bear baby 2 dvd
# P-1562	-0.0215 -0.0017 -0.0030 -1.6985 -0.4389 -0.0083
# S-144	惊 爆 危机 dvd vol-06
# T-144	shock crisis dvd vol-06
# H-144	-0.01822158321738243	shock crisis dvd vol-06
# P-144	-0.1052 -0.0103 -0.0040 -0.0025 -0.0020 -0.0035 -0.0001
# S-1049	银河 英雄 传说 - 20 dvd
# T-1049	legend of the galaxy hero-20 dvd
# H-1049	-0.02871870994567871	legend of the galaxy hero-20 dvd
# P-1049	-0.0262 -0.0021 -0.0194 -0.0040 -0.0738 -0.1034 -0.0007 -0.0000
# S-2428	apm 防水 喷雾 + 水 镀膜
# T-2428	apm waterproof spray + water coating
# H-2428	-0.009417806752026081	apm waterproof spray + water coating
# P-2428	-0.0168 -0.0020 -0.0055 -0.0001 -0.0113 -0.0296 -0.0006
# S-5330	cross 18k 包金 原子笔 2802
# T-5330	cross 18k gold ballpoint pen 2802
# H-5330	-0.020321965217590332	cross 18k gold ballpoint pen 2802
# P-5330	-0.0013 -0.0011 -0.0417 -0.0356 -0.0787 -0.0041 -0.0000 -0.0000
# S-5914	彩云 国 物语 dvd vol-09
# T-5914	caiyun kingdom story dvd vol-09
# H-5914	-0.0380779504776001	caiyun kingdom story dvd vol-09
# P-5914	-0.2185 -0.0177 -0.0325 -0.0050 -0.0007 -0.0059 -0.0244 -0.0000
# S-4521	kid x anybears 旗子 短t
# T-4521	kid x anybears flag short t
# H-4521	-0.8228980898857117	kid x anybble short t
# P-4521	-0.0012 -0.0348 -2.8042 -2.4870 -0.1844 -0.1340 -0.1147
# S-5177	透视 感 网状 交叉 针织 背心
# T-5177	perspective mesh cross-knit vest
# H-5177	-0.10788106918334961	perspective mesh cross knitted vest
# P-5177	-0.0256 -0.0967 -0.1145 -0.0009 -0.2027 -0.4190 -0.0034 -0.0002
# S-2953	惊 爆 危机 dvd vol-03
# T-2953	shock crisis dvd vol-03
# H-2953	-0.02296161837875843	shock crisis dvd vol-03
# P-2953	-0.1311 -0.0066 -0.0041 -0.0033 -0.0036 -0.0121 -0.0000
# S-6567	鸡 老二 大 包装 系列 2
# T-6567	chicken lao er big packing series 2
# H-6567	-0.04662179946899414	chicken lao er big packing series 2
# P-6567	-0.0078 -0.0912 -0.0104 -0.0013 -0.2589 -0.0002 -0.0018 -0.0012
# S-8863	denim blue 牛仔 防震 笔 电包
# T-8863	denim blue denim shockproof laptop bag
# H-8863	-0.03609071671962738	denim blue denim shockproof laptop bag
# P-8863	-0.0011 -0.0011 -0.0129 -0.0043 -0.1715 -0.0545 -0.0072
# S-6792	潘 柔 珍珠 薏仁 洗面乳 230g
# T-6792	pan rou pearl barley cleanser 230g
# H-6792	-0.13285037875175476	pan rou pearl barley cleanser 230g
# P-6792	-0.8400 -0.0425 -0.0016 -0.0043 -0.0389 -0.0027 -0.0000
# S-3970	df 美 肌保 湿 轻盈 组
# T-3970	df beauty skin moisturizing light group
# H-3970	-0.059748969972133636	df beauty moisturizing light group
# P-3970	-0.0006 -0.0974 -0.1178 -0.0097 -0.1329 -0.0001
# S-1097	薙刀 社 青春 日记 dvd
# T-1097	yatosha youth diary dvd
# H-1097	-0.014550345949828625	yatosha youth diary dvd
# P-1097	-0.0171 -0.0482 -0.0317 -0.0007 -0.0038 -0.0001 -0.0002
# S-1353	tsubasa 翼 dvd vol-3
# T-1353	tsubasa wing dvd vol-3
# H-1353	-1.0539186000823975	tsuwings dvd vol-3
# P-1353	-1.9203 -4.3826 -0.0089 -0.0053 -0.0064 -0.0000
# S-7607	小 牛津 欢乐 动物 轨道 车
# T-7607	little oxford happy animal track car
# H-7607	-0.012343407608568668	little oxford happy animal track car
# P-7607	-0.0368 -0.0005 -0.0064 -0.0326 -0.0004 -0.0094 -0.0003
# S-9507	kid 大鲨鱼 短 t白
# T-9507	kid big shark short t white
# H-9507	-0.017309462651610374	kid big shark short t white
# P-9507	-0.0006 -0.0837 -0.0313 -0.0011 -0.0034 -0.0009 -0.0001
# S-2	粉 晶 六角 柱 纯银 项链
# T-2	pink crystal hexagonal sterling silver necklace
# H-2	-0.13717052340507507	pink crystal hexagonal sterling silver necklace
# P-2	-0.1063 -0.0733 -0.5175 -0.0989 -0.0013 -0.1627 -0.0001
# S-3719	日本 桐 灰 衣物 凉感 喷雾
# T-3719	japanese tong gray clothing cooling spray
# H-3719	-0.06744766235351562	japanese tong gray clothing cooling spray
# P-3719	-0.1530 -0.0318 -0.2304 -0.0017 -0.0496 -0.0051 -0.0004
# S-4725	hollister 经典 文字 刺绣 短 t
# T-4725	hollister classic text embroidery short t
# H-4725	-0.019812721759080887	hollister classic text embroidery short t
# P-4725	-0.0009 -0.0006 -0.0092 -0.1274 -0.0004 -0.0002 -0.0000
# S-9606	｜ 现货 ｜ 烘焙 刮 板
# T-9606	｜ in stock ｜ baking scraper
# H-9606	-0.018797194585204124	｜ in stock ｜ baking scraper
# P-9606	-0.0023 -0.0798 -0.0116 -0.0118 -0.0142 -0.0119 -0.0000
# S-21	国际 牌 cr-1632/1b
# T-21	international brand cr-1632 / 1b
# H-21	-0.008066654205322266	international brand cr-1632 / 1b
# P-21	-0.0025 -0.0005 -0.0051 -0.0034 -0.0305 -0.0081 -0.0145 -0.0000
# S-9794	superdry premium neo 迷彩 游泳 短裤
# T-9794	superdry premium neo camo swimming shorts
# H-9794	-0.041457585990428925	superdry premium neo camo swimming shorts
# P-9794	-0.0004 -0.0081 -0.0040 -0.2297 -0.0103 -0.0369 -0.0008
# S-2831	压克力 光影 mt 和 纸 胶带
# T-2831	acrylic light shadow mt and paper tape
# H-2831	-0.023306727409362793	acrylic light shadow mt and paper tape
# P-2831	-0.0093 -0.0820 -0.0892 -0.0029 -0.0014 -0.0009 -0.0006 -0.0000
# S-907	凯 婷 指甲油 速 干 喷雾
# T-907	kai ting nail polish quick dry spray
# H-907	-0.1289362907409668	kai ting nail quick-drying spray
# P-907	-0.2855 -0.0149 -0.0879 -0.3832 -0.0020 -0.0000
# S-1891	银河 英雄 传说 - 28 dvd
# T-1891	legend of the galaxy hero-28 dvd
# H-1891	-0.11318004131317139	legend of the galaxy hero-28 dvd
# P-1891	-0.0313 -0.0023 -0.0224 -0.0036 -0.0579 -0.7872 -0.0007 -0.0000
# S-1807	京都 美食 漫步 冬季 套装 dvd
# T-1807	kyoto food walk winter set dvd
# H-1807	-0.1648409366607666	kyoto food stwinter set dvd
# P-1807	-0.0080 -0.0514 -0.0664 -0.5205 -0.4095 -0.0784 -0.1832 -0.0013
# S-206	高画质 hd- 深海 迷宫 dvd
# T-206	high definition hd-deep sea labyrinth dvd
# H-206	-0.03631746768951416	high definition hd-deep sea labyrinth dvd
# P-206	-0.0911 -0.0492 -0.0141 -0.0248 -0.0539 -0.0573 -0.0002 0.0000
# S-6169	个性 翻领 无袖 剪接 上衣
# T-6169	personalized lapel sleeveless splicing top
# H-6169	-0.1796046942472458	personality lapel sleeveless cut top
# P-6169	-0.6646 -0.0008 -0.0141 -0.3454 -0.0515 -0.0013
# S-9833	神 样 中学生 dvd vol-8
# T-9833	magical middle school student dvd vol-8
# H-9833	-0.06222078576683998	godlike middle school student dvd vol-8
# P-9833	-0.1424 -0.1537 -0.0192 -0.1931 -0.0300 -0.0077 -0.0011 -0.0128 -0.0000
# S-9738	看 卡通 学 成语 1 dvd
# T-9738	learn cartoon idioms 1 dvd
# H-9738	-0.07748496532440186	learn cartoon idioms 1 dvd
# P-9738	-0.2072 -0.0031 -0.3536 -0.0460 -0.0050 -0.0028 -0.0021 -0.0000
# S-4986	七福神 招手 猫 集
# T-4986	seven lucky gods beckoning cat set
# H-4986	-0.08143794536590576	seven lucky gods beckoning cat set
# P-4986	-0.0062 -0.1933 -0.0622 -0.2169 -0.0066 -0.0047 -0.1616 -0.0000
# S-2882	腕力器 手腕 训练器 20736
# T-2882	wrist training wrist training device 20736
# H-2882	-1.2771695852279663	wrist arm strength training ukulele 36
# P-2882	-0.2221 -0.9204 -1.2755 -0.3901 -4.1453 -1.9816 -0.0051
# S-4841	短上衣 + 亮片 星空 纱裙 套装
# T-4841	short top + sequin star skirt suit
# H-4841	-0.1268141269683838	short top + sequin star skirt suit
# P-4841	-0.0045 -0.3352 -0.0011 -0.0754 -0.0287 -0.0593 -0.5102 -0.0001
# S-4050	聚焦 台湾: 彩虹 大道 dvd
# T-4050	spotlight on taiwan : rainbow avenue dvd
# H-4050	-0.025516629219055176	spotlight on taiwan : rainbow avenue dvd
# P-4050	-0.1487 -0.0208 -0.0237 -0.0005 -0.0003 -0.0101 -0.0000 -0.0000
# S-2779	kuku 酷咕 鸭 站 立 牙刷
# T-2779	kuku cool cuckoo standing toothbrush
# H-2779	-0.0485684871673584	kuku cool cuckoo standing toothbrush
# P-2779	-0.0241 -0.0531 -0.1703 -0.0745 -0.0476 -0.0146 -0.0042 -0.0001
# S-2940	帆布鞋 款 鞋 板 鞋 布鞋
# T-2940	canvas shoes shoes shoes shoes cloth shoes
# H-2940	-0.1647808998823166	canvas shoes shoes shoes cloth shoes
# P-2940	-0.0151 -0.0010 -0.0088 -0.0294 -1.0743 -0.0028 -0.0220
# S-5812	牛皮 腰带 平滑 扣 商务 裤带
# T-5812	cowhide belt business buckle with smooth buckle
# H-5812	-0.19871766865253448	cowhide belt smooth buckle business buckle
# P-5812	-0.0462 -0.2468 -0.0705 -0.0549 -0.0827 -0.8762 -0.0138
# S-2027	资生堂 玫瑰园 沐浴乳 浓缩 300 毫升
# T-2027	shiseido rose garden shower milk concentrate 300ml
# H-2027	-0.2528034448623657	shiseido rose garden shower milk concentrate 300ml
# P-2027	-0.0013 -0.5874 -0.0902 -0.0535 -0.1863 -1.0855 -0.0183 0.0000
# S-9860	日 系小 清新 长柄 伞 雨伞
# T-9860	japanese small fresh long handle umbrella umbrella
# H-9860	-0.08961405605077744	japanese small fresh long handle umbrella
# P-9860	-0.0428 -0.0084 -0.0134 -0.0422 -0.0615 -0.0002 -0.4589
# S-8816	泰迪幼犬 中型 小型 犬狗狗 雨衣
# T-8816	teddy puppies medium and small dog raincoat
# H-8816	-0.041231751441955566	teddy puppies medium and small dog raincoat
# P-8816	-0.0139 -0.0099 -0.0080 -0.0618 -0.1373 -0.0933 -0.0056 -0.0000
# S-9828	小鹿斑比 (钻石 特别 版) dvd
# T-9828	bambi ( diamond special edition ) dvd
# H-9828	-0.005835533142089844	bambi ( diamond special edition ) dvd
# P-9828	-0.0029 -0.0001 -0.0037 -0.0027 -0.0356 -0.0017 -0.0001 -0.0000
# S-7525	联盖h型 接地 插座 盖板
# T-7525	h-type grounding socket cover
# H-7525	-0.9718574285507202	friendship cloth socket cover plate
# P-7525	-0.8028 -3.6516 -0.2424 -0.4969 -0.5995 -0.0380
# S-4021	福尔摩斯 - 幽灵 猎犬 dvd
# T-4021	sherlock holmes-ghost hound dvd
# H-4021	-0.10735023021697998	sherlock holmes-ghost hound dvd
# P-4021	-0.0529 -0.0163 -0.0189 -0.0108 -0.0418 -0.7178 -0.0004 -0.0000
# S-6838	gap gap 英式 风情 休闲 短t
# T-6838	gap gap british style casual short t
# H-6838	-0.02575695514678955	gap gap british style casual short t
# P-6838	-0.0003 -0.1072 -0.0107 -0.0049 -0.0209 -0.0586 -0.0004 -0.0030
# S-7950	superdry solo sport 圆领 大学 t
# T-7950	superdry solo sport round collar university t
# H-7950	-0.009538650512695312	superdry solo sport round neck university t
# P-7950	-0.0009 -0.0046 -0.0018 -0.0070 -0.0309 -0.0304 -0.0008 -0.0000
# S-5740	现货 玻尿酸 保 湿 面膜 面膜
# T-5740	spot hyaluronic acid moisturizing mask mask
# H-5740	-0.04645935818552971	spot hyaluronic acid moisturizing mask
# P-5740	-0.1514 -0.0044 -0.0012 -0.0093 -0.0117 -0.1008
# S-8369	英文 肩带 运动 衬垫 小 可爱
# T-8369	english shoulder strap sports pad little cute
# H-8369	-0.05994606018066406	english shoulder strap sports pad little cute
# P-8369	-0.0004 -0.0648 -0.0564 -0.0036 -0.2841 -0.0682 -0.0021 -0.0000
# S-6251	furla 蝴蝶结 拉链 牛皮 长 夹
# T-6251	furla bow zipper cowhide long clip
# H-6251	-0.06446130573749542	furla bow zipper cowhide long clip
# P-6251	-0.0016 -0.0058 -0.0184 -0.3872 -0.0075 -0.0307 -0.0001
# S-9274	日本 inomata 胶带 收纳 切割 盒
# T-9274	japan <<unk>> tape storage cutting box
# H-9274	-0.05427384376525879	japan inomata tape storage cutting box
# P-9274	-0.3745 -0.0189 -0.0153 -0.0068 -0.0017 -0.0032 -0.0137 -0.0001
# S-4152	皮带 针 扣 牛皮 双面 旋转
# T-4152	belt pin buckle leather double-sided rotation
# H-4152	-0.08768109232187271	belt pin buckle leather double-sided rotation
# P-4152	-0.0041 -0.0290 -0.0006 -0.0757 -0.0075 -0.4969 -0.0001
# S-237	brosway grace 点点 丝巾
# T-237	brosway grace little scarf
# H-237	-0.009368896484375	brosway grace little scarf
# P-237	-0.0034 -0.0009 -0.0138 -0.0103 -0.0166 -0.0205 -0.0001
# S-932	天 丝 蛋 型 九分 裤
# T-932	tencel egg-shaped cropped pants
# H-932	-0.08530426770448685	tencel egg-shaped cropped pants
# P-932	-0.0503 -0.0556 -0.0798 -0.0770 -0.3253 -0.0093 -0.0000
# S-6598	outerspace 官方 os pizza 太空 伞
# T-6598	outerspace official os pizza space umbrella
# H-6598	-0.0096119474619627	outerspace official os pizza space umbrella
# P-6598	-0.0007 -0.0004 -0.0000 -0.0645 -0.0007 -0.0009 -0.0000
# S-1413	crystal ball (kaylee)
# T-1413	crystal ball ( kaylee )
# H-1413	-0.015661103650927544	crystal ball ( kaylee )
# P-1413	-0.0035 -0.0003 -0.0000 -0.0762 -0.0294 -0.0002 -0.0000
# S-6579	tobot 机器 战士 迷你 冒险 w
# T-6579	tobot robot warrior mini adventure w
# H-6579	-0.0033114298712462187	tobot robot warrior mini adventure w
# P-6579	-0.0048 -0.0103 -0.0019 -0.0000 -0.0005 -0.0055 -0.0002
# S-492	点点 风 蝴蝶结 收 腰 洋装
# T-492	little wind bow tie waist dress
# H-492	-0.06223869323730469	little wind bow waist dress
# P-492	-0.0808 -0.0596 -0.0304 -0.1999 -0.0027 -0.0000
# S-5620	hermes twilly under the waves 丝巾
# T-5620	hermes twilly under the waves scarf
# H-5620	-0.07269056141376495	hermes twilly under the waves scarf
# P-5620	-0.0134 -0.0087 -0.0004 -0.0005 -0.4852 -0.0006 -0.0000
# S-2067	crystal ball (vintage medal)
# T-2067	crystal ball ( vintage medal )
# H-2067	-0.0022772380616515875	crystal ball ( vintage medal )
# P-2067	-0.0009 -0.0007 -0.0000 -0.0012 -0.0131 -0.0000 -0.0000
# S-196	12 生肖 狗 玩具 - 龙
# T-196	12 zodiac dog toys-dragon
# H-196	-0.0873161107301712	12 zodiac dog toys-dragon
# P-196	-0.2874 -0.0257 -0.0420 -0.2180 -0.0298 -0.0081 -0.0002
# S-3426	肤蕊 深层 净化 卸妆 油
# T-3426	skin core deep purifying cleansing oil
# H-3426	-0.134918212890625	skin core deep purifying makeup remover
# P-3426	-0.0386 -0.0324 -0.0743 -0.1811 -0.1041 -0.5137 -0.0001
# S-955	blu-ray 恶 狼 idbd
# T-955	blu-ray bad wolf idbd
# H-955	-0.0181688591837883	blu-ray bad wolf idbd
# P-955	-0.0033 -0.1079 -0.0092 -0.0016 -0.0049 -0.0002 -0.0002
# S-9663	outerspace 官方 ma1 织带 口袋 短裤
# T-9663	outerspace official <<unk>> web pocket shorts
# H-9663	-0.14799273014068604	outerspace official ma1 web pocket shorts
# P-9663	-0.0010 -0.0002 -0.0258 -0.0241 -1.0734 -0.0369 -0.0225 -0.0001
# S-7124	a'pieu pro 质感 修 容 腮红
# T-7124	a & # 39 ; pieu pro texture blush
# H-7124	-0.21742241084575653	a & # 39 ; pieu pro texture blush
# P-7124	-0.0013 -0.0020 -0.0032 -0.0001 -0.0009 -0.0103 -0.0009 -0.0208 -0.1928 -2.1265 -0.0329
# S-558	素面 针织 毛衣 dp01008
# T-558	plain knitted sweater dp01008
# H-558	-0.010220391675829887	plain knitted sweater dp01008
# P-558	-0.0028 -0.0114 -0.0063 -0.0010 -0.0038 -0.0463 -0.0000
# S-5670	crystal ball (military rose)
# T-5670	crystal ball ( military rose )
# H-5670	-0.3539073169231415	crystal ball ( rosewood )
# P-5670	-0.0010 -0.0003 -0.0002 -1.8535 -0.6191 -0.0032 -0.0000
# S-1017	狂 砂 小子 dvd vol-01
# T-1017	mad sand boy dvd vol-01
# H-1017	-0.026102475821971893	mad sand boy dvd vol-01
# P-1017	-0.0054 -0.0625 -0.0345 -0.0002 -0.0017 -0.0785 0.0000
# S-6590	ohbases 小小 滋润 面霜
# T-6590	ohbases little moisturizing cream
# H-6590	-0.017941884696483612	ohbases little moisturizing cream
# P-6590	-0.0047 -0.0037 -0.0027 -0.1011 -0.0076 -0.0056 -0.0000
# S-4912	9 孔 简易 雨伞 收纳 架
# T-4912	9-hole simple umbrella storage rack
# H-4912	-0.05026872083544731	9 hole simple umbrella storage rack
# P-4912	-0.2524 -0.0096 -0.0020 -0.0215 -0.0308 -0.0354 -0.0001
# S-4	灯 专属 优惠 * 4 盒
# T-4	exclusive lamp offer * 4 boxes
# H-4	-0.21049977838993073	exclusive lamp offer * 4 boxes
# P-4	-0.0914 -1.1244 -0.1899 -0.0010 -0.0015 -0.0649 -0.0005
# S-5928	珍珠 叶片 胸针 别针 15244
# T-5928	pearl leaf brooch pin 15244
# H-5928	-0.019557680934667587	pearl leaf brooch pin 15244
# P-5928	-0.0133 -0.1140 -0.0072 -0.0001 -0.0005 -0.0017 -0.0000
# S-5727	hedgren hedgren world explorer 公事包 -
# T-5727	hedgren hedgren world explorer briefcase-
# H-5727	-0.23791654407978058	hedgren hedgren world explorer briefcase-
# P-5727	-0.0008 -0.4673 -0.0053 -0.0627 -0.0873 -1.0420 -0.0000
# S-4259	fitbit alt hr 智能 健身 手表
# T-4259	fitbit alt hr smart fitness watch
# H-4259	-0.004162924829870462	fitbit alt hr smart fitness watch
# P-4259	-0.0020 -0.0108 -0.0082 -0.0028 -0.0030 -0.0018 -0.0006
# S-5161	lesportsac 深色 花样 日常 化妆 包
# T-5161	lesportsac dark pattern daily cosmetic bag
# H-5161	-0.018863677978515625	lesportsac dark pattern daily cosmetic bag
# P-5161	-0.0003 -0.0017 -0.0047 -0.0009 -0.1067 -0.0177 -0.0001
# S-1402	blu-ray 寻找 甜 秘 客 bd
# T-1402	blu-ray looking for sweet secret bd
# H-1402	-0.012997082434594631	blu-ray looking for sweet secret bd
# P-1402	-0.0181 -0.0105 -0.0311 -0.0297 -0.0009 -0.0007 -0.0000
# S-9892	kate spade 甜美 蝴蝶结 条纹 托特包
# T-9892	kate spade sweet bow stripe tote
# H-9892	-0.020099639892578125	kate spade sweet bow stripe tote
# P-9892	-0.0002 -0.0004 -0.0015 -0.0061 -0.1261 -0.0057 -0.0007
# S-7857	nubra 隐形 胸罩 seamless push up
# T-7857	nubra invisible bra seamless push up
# H-7857	-0.03331498056650162	nubra invisible bra seamless push up
# P-7857	-0.0009 -0.0003 -0.0011 -0.2220 -0.0043 -0.0000 -0.0046
# S-5132	outerspace 官方 gold 长 剪裁 袜
# T-5132	outerspace official gold long cut socks
# H-5132	-0.004978997632861137	outerspace official gold long cut socks
# P-5132	-0.0007 -0.0004 -0.0082 -0.0028 -0.0151 -0.0076 -0.0000
# S-3754	gopro 副 厂 冲浪 配件 底座
# T-3754	gopro vice factory surfing accessories base
# H-3754	-0.012971470132470131	gopro vice factory surfing accessories base
# P-3754	-0.0007 -0.0342 -0.0080 -0.0283 -0.0173 -0.0018 -0.0004
# S-6766	奶 梅 300g 臻 御行
# T-6766	milk plum 300g zhen yu xing
# H-6766	-0.019174849614501	milk plum 300g zhen yu xing
# P-6766	-0.0051 -0.0299 -0.0075 -0.0073 -0.0748 -0.0096 -0.0001
# S-6231	鸡 老二 大 包装 狗 零食
# T-6231	chicken chow big dog snack
# H-6231	-0.10682065784931183	chicken lao er big packing snack
# P-6231	-0.0074 -0.1335 -0.0139 -0.0018 -0.5229 -0.0678 -0.0005
# S-7462	陶瓷 娃娃 系列 dd 霜 45ml
# T-7462	ceramic doll series dd cream 45ml
# ...
# H-5769	-0.09766475111246109	hamee japanese bottle making series stationery envelope set universal card creative design stationery ( hedgehog ) km06019
# P-5769	-0.0062 -0.0008 -0.0299 -0.0322 -0.2892 -0.0224 -0.9894 -0.0322 -0.0235 -0.0234 -0.1406 -0.0060 -0.0235 -0.0096 -0.0001 -0.3888 -0.0017 -0.0004 -0.0004 -0.0100 -0.2040 -0.0115 -0.0005
# S-1530	benz 气 嘴 盖 气门 嘴 风嘴 glk ml350 r350 g350 slk 55 amg cls500 s 63 cl
# H-7859	-0.3538414239883423	tinkerbell & # 39 ; s shop-fjh2178 & quot ; miao & quot ; successful piano teaching book-level cd
# P-7859	-0.1790 -0.0003 -0.0016 -0.0001 -0.0000 -0.0004 -0.0004 -0.0178 -0.9588 -0.2172 -0.0006 -0.0008 -0.0001 -0.0000 -0.2425 -1.5758 -2.2366 -0.0001 -0.0004 -0.0001 -0.3386 -0.0495 -0.5124 -1.7923 -0.0504 -0.4849 -0.8915 -0.3555
# S-2104	牛仔 短裤 薄 款 中老年 加肥 加大 男士 棉 质 牛仔 七 分 裤 宽松 大 码 弹力 yx042813
# T-2104	denim shorts thin section middle-aged and elderly plus fat increase men & # 39 ; s cotton denim cropped pants loose large size elasticity yx042813
# H-2104	-0.0894765555858612	denim shorts thin section middle-aged and elderly plus fertilizer men & # 39 ; s cotton denim cropped pants loose large size elasticity yx042813
# P-2104	-0.0029 -0.0642 -0.0062 -0.0801 -0.0183 -0.0288 -0.0128 -0.0034 -0.0186 -0.3253 -0.0161 -0.0064 -0.4769 -0.6696 -0.0979 -0.0019 -0.0000 -0.0000 -0.0000 -0.0000 -0.1767 -0.0910 -0.0623 -0.0488 -0.0299 -0.0837 -0.0123 -0.7031 -0.0003 -0.0008 -0.0018 -0.0020 -0.0004 -0.0000
# S-4764	强 尼 拍卖 ~ cooyee apple iphone 6/6s plus 3d满 版 玻璃 贴 (亮 面) (全 胶) 玻璃 贴 9h
# T-4764	johnny auction ~ cooyee apple iphone 6 / 6s plus 3d full version glass sticker ( glossy ) ( full glue ) glass sticker 9h
#                                                                                 full version glass sticker ( glossy ) ( full glue ) 9h
# P-4764	-0.0309 -0.0007 -0.0024 -0.0001 -0.0021 -0.0035 -0.0001 -0.0027 -0.0109 -0.0212 -0.0055 -0.0156 -0.0506 -0.0053 -0.0015 -0.0048 -0.0081 -0.0159 -0.0004 -0.0569 -0.0032 -0.0152 -0.0712 -0.0286 -0.0019 -1.1441 -0.2039
# | Translated 10000 sentences (143100 tokens) in 27.4s (364.31 sentences/s, 5213.25 tokens/s)
# | Generate test with beam=8: BLEU4 = 82.11, 92.5/85.8/80.3/75.6 (BP=0.985, ratio=0.986, syslen=108313, reflen=109900)

# %% [markdown]
# ### Postprocess output

# %%
import pandas as pd
import numpy as np
import io

# %%
f = io.open("preds.out", mode="r", encoding="utf-8")
data = f.readlines()

# %%
sentences = []
for line in data:
    if line[0] == 'H':
        l, p, s = line.split('\t')
        l = int(l[2:])
        s = s.strip()
        sentences.append([l, s])

# %%
sentences.sort()
sentences = np.array(sentences)

# %%
df_submission = pd.DataFrame({'translation_output':sentences[:,1]})
df_submission.head()
# Out:
#                                   translation_output
# 0  [ polarstar ] beautiful wool warm socks & quot...
# 1  sweet crystal ~ natural crystal five elements ...
# 2    pink crystal hexagonal sterling silver necklace
# 3  3m scotch vhb super strong double-sided tape-o...
# 4                     exclusive lamp offer * 4 boxes

# %%
df_submission.to_csv('submission.csv', index=False)

# %%
# !gsutil cp submission.csv gs://shopee-title-translation/mass/submission_pc.csv
